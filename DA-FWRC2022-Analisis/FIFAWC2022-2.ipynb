# %%
import pandas as pd

df = pd.read_csv('df_fifawc2022.csv')
df = df.reset_index()
df = df.drop("index", axis=1)

df.columns = [col.replace(' ', '_') for col in df.columns]

teams = df[['team1', 'team2']].values.ravel()
teams = pd.unique(teams)

consolidated_data = []

for team in teams:
    team_data = {}
    for column in df.columns:
        # Excluir 'team1', 'team2' y 'Unnamed: 0'
        if column == 'team1' or column == 'team2' or column == 'Unnamed: 0':
            continue

        team1_values = df.loc[df['team1'] == team, column]
        team2_values = df.loc[df['team2'] == team, column]

        if '_team1' in column or '_team2' in column:
            team_data[column.replace('_team1', '').replace('_team2', '')] = (team1_values.sum() + team2_values.sum())
        else:
            all_values = pd.concat([team1_values.reset_index(drop=True),
                                    team2_values.reset_index(drop=True)])
            team_data[column] = all_values.mean()

    consolidated_data.append(team_data)

consolidated_df = pd.DataFrame(consolidated_data, index=teams)
print(consolidated_df)
# Out:
#                 Unnamed:_0  possession  possession_in_contest  \
# QATAR            16.333333        1.36               0.086667
# ECUADOR          17.000000        1.21               0.126667
# ENGLAND          32.800000        1.88               0.098000
# IRAN             17.333333        0.97               0.126667
# SENEGAL          25.750000        1.60               0.122500
# NETHERLANDS      31.400000        2.20               0.112000
# UNITED STATES    26.250000        1.78               0.112500
# WALES            17.666667        1.30               0.120000
# ARGENTINA        42.000000        3.00               0.120000
# SAUDI ARABIA     21.333333        1.36               0.143333
# DENMARK          21.000000        1.37               0.133333
# TUNISIA          20.666667        1.20               0.150000
# MEXICO           22.666667        1.22               0.153333
# POLAND           28.750000        1.97               0.120000
# FRANCE           42.714286        3.08               0.114286
# AUSTRALIA        28.000000        1.61               0.140000
# MOROCCO          44.142857        3.58               0.114286
# CROATIA          43.428571        3.45               0.115714
# GERMANY          26.333333        1.15               0.123333
# JAPAN            31.750000        1.90               0.120000
# SPAIN            33.250000        1.96               0.095000
# COSTA RICA       25.666667        1.16               0.116667
# BELGIUM          25.333333        1.22               0.110000
# CANADA           26.000000        1.25               0.120000
# SWITZERLAND      35.750000        1.75               0.107500
# CAMEROON         29.000000        1.51               0.123333
# URUGUAY          29.333333        1.12               0.133333
# KOREA REPUBLIC   35.000000        1.69               0.120000
# PORTUGAL         40.600000        2.38               0.110000
# GHANA            29.000000        1.06               0.133333
# BRAZIL           40.200000        2.19               0.108000
# SERBIA           29.666667        1.24               0.133333
#
#                 number_of_goals  total_attempts  conceded  \
# QATAR                         5              24         3
# ECUADOR                       5              34         2
# ENGLAND                       7              54        10
# IRAN                          5              41         6
# SENEGAL                       7              46         5
# NETHERLANDS                   6              61         8
# UNITED STATES                 3              47         4
# WALES                         6              45         1
# ARGENTINA                    10              74        13
# SAUDI ARABIA                  4              44         4
# DENMARK                       1              35         3
# TUNISIA                       1              28         1
# MEXICO                        2              37         3
# POLAND                        3              60         5
# FRANCE                        8              66        16
# AUSTRALIA                     3              31         7
# MOROCCO                       5              68         6
# CROATIA                       4              85        11
# GERMANY                       7              52         4
# JAPAN                         5              44         4
# SPAIN                         2              37        10
# COSTA RICA                    5              36         9
# BELGIUM                       2              47         1
# CANADA                        3              37         6
# SWITZERLAND                   4              35        10
# CAMEROON                      3              42         5
# URUGUAY                       2              28         2
# KOREA REPUBLIC                5              36         8
# PORTUGAL                      4              51        14
# GHANA                         7              28         5
# BRAZIL                        2              57         9
# SERBIA                        6              34         7
#
#                 goal_inside_the_penalty_area  goal_outside_the_penalty_area  \
# QATAR                                      5                              0
# ECUADOR                                    5                              0
# ENGLAND                                    5                              2
# IRAN                                       4                              1
# SENEGAL                                    7                              0
# NETHERLANDS                                6                              0
# UNITED STATES                              3                              0
# WALES                                      4                              2
# ARGENTINA                                  9                              0
# SAUDI ARABIA                               3                              1
# DENMARK                                    1                              0
# TUNISIA                                    1                              0
# MEXICO                                     1                              1
# POLAND                                     3                              0
# FRANCE                                     7                              1
# AUSTRALIA                                  2                              0
# MOROCCO                                    4                              1
# CROATIA                                    4                              0
# GERMANY                                    7                              0
# JAPAN                                      5                              0
# SPAIN                                      2                              0
# COSTA RICA                                 5                              0
# BELGIUM                                    2                              0
# CANADA                                     2                              1
# SWITZERLAND                                4                              0
# CAMEROON                                   2                              1
# URUGUAY                                    2                              0
# KOREA REPUBLIC                             4                              1
# PORTUGAL                                   4                              0
# GHANA                                      7                              0
# BRAZIL                                     1                              1
# SERBIA                                     5                              1
#
#                 assists  on_target_attempts  ...  crosses  crosses_completed  \
# QATAR                 3                  11  ...       50                 14
# ECUADOR               1                  13  ...       56                 13
# ENGLAND               5                  19  ...       67                 19
# IRAN                  3                  14  ...       56                  7
# SENEGAL               3                  14  ...       78                 22
# NETHERLANDS           3                  25  ...      106                 22
# UNITED STATES         2                  17  ...       80                 12
# WALES                 3                  16  ...       58                 17
# ARGENTINA             5                  32  ...      123                 24
# SAUDI ARABIA          2                  17  ...       67                 12
# DENMARK               1                   6  ...       63                 12
# TUNISIA               1                   6  ...       56                 12
# MEXICO                1                  12  ...       61                 12
# POLAND                2                  22  ...       74                 18
# FRANCE                5                  20  ...      124                 28
# AUSTRALIA             2                   8  ...       79                 13
# MOROCCO               3                  15  ...      137                 26
# CROATIA               3                  28  ...      158                 41
# GERMANY               6                  18  ...       67                 16
# JAPAN                 4                  13  ...       76                 14
# SPAIN                 2                  10  ...       65                  7
# COSTA RICA            5                  12  ...       48                 12
# BELGIUM               2                  12  ...       52                 18
# CANADA                2                   8  ...       41                 12
# SWITZERLAND           3                  11  ...       59                 12
# CAMEROON              3                  15  ...       71                 16
# URUGUAY               1                  10  ...       52                 12
# KOREA REPUBLIC        3                  13  ...       68                 14
# PORTUGAL              3                  14  ...      100                 22
# GHANA                 5                  13  ...       40                 11
# BRAZIL                1                  23  ...       91                 21
# SERBIA                6                  13  ...       49                 11
# KOREA REPUBLIC               260                         1117
# PORTUGAL                     311                         1326
# GHANA                        241                          943
# BRAZIL                       363                         1660
# SERBIA                       234                          825
#
# [32 rows x 42 columns]

# %%
sorted_stats = {}

# Iterar sobre cada columna (estadística)
for stat in consolidated_df.columns:
    sorted_stats[stat] = consolidated_df[stat].sort_values(ascending=False).index.tolist()

# Convertir a DataFrame (opcional)
sorted_stats_df = pd.DataFrame(sorted_stats)

sorted_stats_df
# Out:
#         Unnamed:_0      possession possession_in_contest number_of_goals  \
# 0          MOROCCO         MOROCCO                MEXICO       ARGENTINA
# 1          CROATIA         CROATIA               TUNISIA          FRANCE
# 2           FRANCE          FRANCE          SAUDI ARABIA         ENGLAND
# 3        ARGENTINA       ARGENTINA             AUSTRALIA           GHANA
# 4         PORTUGAL        PORTUGAL               URUGUAY         SENEGAL
# 5           BRAZIL     NETHERLANDS               DENMARK         GERMANY
# 6      SWITZERLAND          BRAZIL                SERBIA          SERBIA
# 7   KOREA REPUBLIC          POLAND                 GHANA     NETHERLANDS
# 8            SPAIN           SPAIN                  IRAN           WALES
# 9          ENGLAND           JAPAN               ECUADOR  KOREA REPUBLIC
# 10           JAPAN         ENGLAND               GERMANY      COSTA RICA
# 11     NETHERLANDS   UNITED STATES              CAMEROON           JAPAN
# 12          SERBIA     SWITZERLAND               SENEGAL         ECUADOR
# 13         URUGUAY  KOREA REPUBLIC                 JAPAN           QATAR
# 14           GHANA       AUSTRALIA                 WALES         MOROCCO
# 15        CAMEROON         SENEGAL             ARGENTINA            IRAN
# 16          POLAND        CAMEROON        KOREA REPUBLIC         CROATIA
# 17       AUSTRALIA         DENMARK                CANADA        PORTUGAL
# 18         GERMANY           QATAR                POLAND    SAUDI ARABIA
# 19   UNITED STATES    SAUDI ARABIA            COSTA RICA     SWITZERLAND
# 20          CANADA           WALES               CROATIA       AUSTRALIA
# 21         SENEGAL          CANADA                FRANCE   UNITED STATES
# 22      COSTA RICA          SERBIA               MOROCCO        CAMEROON
# 23         BELGIUM         BELGIUM         UNITED STATES          POLAND
# 24          MEXICO          MEXICO           NETHERLANDS          CANADA
# 25    SAUDI ARABIA         ECUADOR              PORTUGAL         BELGIUM
# 26         DENMARK         TUNISIA               BELGIUM           SPAIN
# 27         TUNISIA      COSTA RICA                BRAZIL         URUGUAY
# 28           WALES         GERMANY           SWITZERLAND          MEXICO
# 29            IRAN         URUGUAY               ENGLAND          BRAZIL
# 30         ECUADOR           GHANA                 SPAIN         DENMARK
# 31           QATAR            IRAN                 QATAR         TUNISIA
#
#     total_attempts        conceded goal_inside_the_penalty_area  \
# 0          CROATIA          FRANCE                    ARGENTINA
# 1        ARGENTINA        PORTUGAL                       FRANCE
# 2          MOROCCO       ARGENTINA                        GHANA
# 3           FRANCE         CROATIA                      SENEGAL
# 4      NETHERLANDS         ENGLAND                      GERMANY
# 5           POLAND     SWITZERLAND                  NETHERLANDS
# 6           BRAZIL           SPAIN                        QATAR
# 7          ENGLAND          BRAZIL                   COSTA RICA
# 8          GERMANY      COSTA RICA                        JAPAN
# 9         PORTUGAL     NETHERLANDS                      ECUADOR
# 10   UNITED STATES  KOREA REPUBLIC                       SERBIA
# 11         BELGIUM          SERBIA                      ENGLAND
# 12         SENEGAL       AUSTRALIA                         IRAN
# 13           WALES          CANADA                        WALES
# 14           JAPAN         MOROCCO                     PORTUGAL
# 15    SAUDI ARABIA            IRAN               KOREA REPUBLIC
# 16        CAMEROON          POLAND                  SWITZERLAND
# 17            IRAN        CAMEROON                      MOROCCO
# 18           SPAIN           GHANA                      CROATIA
# 19          CANADA         SENEGAL                UNITED STATES
# 20          MEXICO   UNITED STATES                 SAUDI ARABIA
# 21      COSTA RICA    SAUDI ARABIA                       POLAND
# 22  KOREA REPUBLIC           JAPAN                        SPAIN
# 23         DENMARK         GERMANY                      BELGIUM
# 24     SWITZERLAND         DENMARK                       CANADA
# 25          SERBIA          MEXICO                     CAMEROON
# 26         ECUADOR           QATAR                      URUGUAY
# 27       AUSTRALIA         ECUADOR                    AUSTRALIA
# 28         URUGUAY         URUGUAY                       MEXICO
# 29           GHANA         BELGIUM                      DENMARK
# 30         TUNISIA           WALES                       BRAZIL
# 31           QATAR         TUNISIA                      TUNISIA
#
#    goal_outside_the_penalty_area         assists on_target_attempts  ...  \
# 0                        ENGLAND          SERBIA          ARGENTINA  ...
# 1                          WALES         GERMANY            CROATIA  ...
# 2                        MOROCCO          FRANCE        NETHERLANDS  ...
# 3                         MEXICO         ENGLAND             BRAZIL  ...
# 4                         BRAZIL           GHANA             POLAND  ...
# 5                 KOREA REPUBLIC       ARGENTINA             FRANCE  ...
# 6                       CAMEROON      COSTA RICA            ENGLAND  ...
# 7                         CANADA           JAPAN            GERMANY  ...
# 8                         FRANCE        PORTUGAL       SAUDI ARABIA  ...
# 9                         SERBIA  KOREA REPUBLIC      UNITED STATES  ...
# 10                  SAUDI ARABIA        CAMEROON              WALES  ...
# 11                          IRAN     SWITZERLAND           CAMEROON  ...
# 12                       DENMARK         CROATIA            MOROCCO  ...
# 13                       BELGIUM           QATAR           PORTUGAL  ...
# 14                         GHANA         MOROCCO            SENEGAL  ...
# 15                      PORTUGAL            IRAN               IRAN  ...
# 16                       SENEGAL         SENEGAL              JAPAN  ...
# 17                       URUGUAY     NETHERLANDS              GHANA  ...
# 18                   NETHERLANDS           WALES     KOREA REPUBLIC  ...
# 19                   SWITZERLAND         BELGIUM             SERBIA  ...
# 20                 UNITED STATES   UNITED STATES            ECUADOR  ...
# 21                    COSTA RICA       AUSTRALIA         COSTA RICA  ...
# 22                       TUNISIA          POLAND            BELGIUM  ...
# 23                         SPAIN    SAUDI ARABIA             MEXICO  ...
# 24                         JAPAN           SPAIN        SWITZERLAND  ...
# 25                       GERMANY          CANADA              QATAR  ...
# 26                       CROATIA         DENMARK              SPAIN  ...
# 27                       ECUADOR         URUGUAY            URUGUAY  ...
# 28                     AUSTRALIA         TUNISIA             CANADA  ...
# 29                     ARGENTINA          MEXICO          AUSTRALIA  ...
# 30                        POLAND         ECUADOR            TUNISIA  ...
# 31                         QATAR          BRAZIL            DENMARK  ...
#
#            crosses crosses_completed switches_of_play_completed  \
# 0          CROATIA           CROATIA                    MOROCCO
# 1          MOROCCO            FRANCE                    CROATIA
# 2           FRANCE           MOROCCO                  ARGENTINA
# 3        ARGENTINA         ARGENTINA                     FRANCE
# 4      NETHERLANDS           SENEGAL             KOREA REPUBLIC
# 5         PORTUGAL       NETHERLANDS                     POLAND
# 6           BRAZIL          PORTUGAL                     BRAZIL
# 7    UNITED STATES            BRAZIL                      QATAR
# 8        AUSTRALIA           ENGLAND                    SENEGAL
# 9          SENEGAL           BELGIUM                   PORTUGAL
# 10           JAPAN            POLAND                NETHERLANDS
# 11          POLAND             WALES                     CANADA
# 12        CAMEROON          CAMEROON                      JAPAN
# 13  KOREA REPUBLIC           GERMANY                    DENMARK
# 14    SAUDI ARABIA    KOREA REPUBLIC                  AUSTRALIA
# 15         GERMANY             JAPAN               SAUDI ARABIA
# 16         ENGLAND             QATAR              UNITED STATES
# 17           SPAIN           ECUADOR                SWITZERLAND
# 18         DENMARK         AUSTRALIA                      SPAIN
# 19          MEXICO            MEXICO                    BELGIUM
# 20     SWITZERLAND        COSTA RICA                    ENGLAND
# 21           WALES           TUNISIA                     SERBIA
# 22         TUNISIA            CANADA                      WALES
# 23         ECUADOR       SWITZERLAND                    ECUADOR
# 24            IRAN           DENMARK                    URUGUAY
# 25         BELGIUM           URUGUAY                   CAMEROON
# 26         URUGUAY      SAUDI ARABIA                       IRAN
# 27           QATAR     UNITED STATES                 COSTA RICA
# 28          SERBIA             GHANA                      GHANA
# 29      COSTA RICA            SERBIA                    GERMANY
# 30          CANADA             SPAIN                     MEXICO
# 31           GHANA              IRAN                    TUNISIA
#
#            corners      free_kicks penalties_scored goal_preventions  \
# 0        ARGENTINA       ARGENTINA        ARGENTINA           FRANCE
# 1          MOROCCO         MOROCCO           FRANCE          CROATIA
# 2          CROATIA         CROATIA          ECUADOR        ARGENTINA
# 3           BRAZIL     NETHERLANDS            QATAR          MOROCCO
# 4      NETHERLANDS          FRANCE          ENGLAND           BRAZIL
# 5          GERMANY        PORTUGAL             IRAN         PORTUGAL
# 6         PORTUGAL          BRAZIL          SENEGAL   KOREA REPUBLIC
# 7           FRANCE         ENGLAND      NETHERLANDS            JAPAN
# 8          SENEGAL         SENEGAL    UNITED STATES        AUSTRALIA
# 9           POLAND     SWITZERLAND            WALES          ENGLAND
# 10   UNITED STATES           JAPAN           POLAND      NETHERLANDS
# 30         ENGLAND            QATAR                       WALES
# 31          SERBIA          ECUADOR                     DENMARK
#
# [32 rows x 42 columns]

# %%
import pandas as pd

top_teams = {}
for column in consolidated_df.columns:
  top_teams[column] = consolidated_df.sort_values(by=column, ascending=False).iloc[0].name

# Contar las veces que cada equipo aparece como "top"
from collections import Counter
top_team_counts = Counter(top_teams.values())

# Obtener los 3 equipos que más aparecen como "top"
top_4_teams = top_team_counts.most_common(4)  # Obtener los 3 más comunes

print("Los 4 mejores equipos que más veces lideran las estadísticas son:")
for team, count in top_4_teams:
    print(f"{team}: {count} veces")
# Out:
# Los 4 mejores equipos que más veces lideran las estadísticas son:
# CROATIA: 12 veces
# MOROCCO: 11 veces
# ARGENTINA: 10 veces
# FRANCE: 4 veces

# %%
argentina_stats = []
for column in consolidated_df.columns:
  top_team = consolidated_df.sort_values(by=column, ascending=False).iloc[0].name
  if top_team == 'ARGENTINA':
    argentina_stats.append(column)

print("Estadísticas en las que Argentina es líder:")
for stat in argentina_stats:
  print(stat)
# Out:
# Estadísticas en las que Argentina es líder:
# number_of_goals
# goal_inside_the_penalty_area
# on_target_attempts
# yellow_cards
# fouls_against
# corners
# free_kicks
# penalties_scored
# forced_turnovers
# defensive_pressures_applied

# %%
import pandas as pd
from collections import Counter

top_4_appearances = []
for column in consolidated_df.columns:
  top_4_teams = consolidated_df.sort_values(by=column, ascending=False).head(4).index.tolist()
  if 'ARGENTINA' in top_4_teams:
    top_4_appearances.append('ARGENTINA')

argentina_count = Counter(top_4_appearances)['ARGENTINA']
total_estadisticas = consolidated_df.shape[1]

print(f"Argentina aparece entre los 4 primeros en {argentina_count} estadísticas.")
print(f"El total de estadísticas analizadas es: {total_estadisticas}")
# Out:
# Argentina aparece entre los 4 primeros en 34 estadísticas.
# El total de estadísticas analizadas es: 42

# %%
argentina_stats = []
for column in consolidated_df.columns:
  top_4_teams = consolidated_df.sort_values(by=column, ascending=False).head(4).index.tolist()
  if 'ARGENTINA' in top_4_teams:
    argentina_stats.append(column)

print("Estadísticas en las que Argentina está entre los 4 primeros:")
for stat in argentina_stats:
  print(stat)
# Out:
# Estadísticas en las que Argentina está entre los 4 primeros:
# Unnamed:_0
# possession
# number_of_goals
# total_attempts
# conceded
# goal_inside_the_penalty_area
# on_target_attempts
# off_target_attempts
# attempts_inside_the_penalty_area
# attempts_inside_the_penalty_area_
# attempts_outside_the_penalty_area_
# central_channel
# total_offers_to_receive
# inbehind_offers_to_receive
# inbetween_offers_to_receive
# infront_offers_to_receive
# receptions_between_midfield_and_defensive_lines
# attempted_line_breaks
# completed_line_breaks
# attempted_defensive_line_breaks
# completed_defensive_line_breaks
# yellow_cards
# fouls_against
# passes
# passes_completed
# crosses
# crosses_completed
# switches_of_play_completed
# corners
# free_kicks
# penalties_scored
# goal_preventions
# forced_turnovers
# defensive_pressures_applied
